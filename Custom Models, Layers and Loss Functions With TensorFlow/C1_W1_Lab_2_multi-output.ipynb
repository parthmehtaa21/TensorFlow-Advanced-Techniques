# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 275.2877 - y1_output_loss: 125.4090 - y2_output_loss: 147.4254 - y1_output_root_mean_squared_error: 11.2512 - y2_output_root_mean_squared_error: 12.1942 - val_loss: 30.7997 - val_y1_output_loss: 15.1553 - val_y2_output_loss: 16.0905 - val_y1_output_root_mean_squared_error: 3.8925 - val_y2_output_root_mean_squared_error: 3.9558
# Epoch 2/500
# 614/614 [==============================] - 0s 143us/sample - loss: 29.5273 - y1_output_loss: 12.1271 - y2_output_loss: 17.2360 - y1_output_root_mean_squared_error: 3.4963 - y2_output_root_mean_squared_error: 4.1597 - val_loss: 27.9571 - val_y1_output_loss: 11.4413 - val_y2_output_loss: 17.4061 - val_y1_output_root_mean_squared_error: 3.3937 - val_y2_output_root_mean_squared_error: 4.0546
# Epoch 3/500
# 614/614 [==============================] - 0s 140us/sample - loss: 29.8731 - y1_output_loss: 11.0476 - y2_output_loss: 18.6716 - y1_output_root_mean_squared_error: 3.3245 - y2_output_root_mean_squared_error: 4.3383 - val_loss: 38.3015 - val_y1_output_loss: 15.4450 - val_y2_output_loss: 24.8408 - val_y1_output_root_mean_squared_error: 3.8862 - val_y2_output_root_mean_squared_error: 4.8165
# Epoch 4/500
# 614/614 [==============================] - 0s 131us/sample - loss: 24.6056 - y1_output_loss: 9.8163 - y2_output_loss: 14.8216 - y1_output_root_mean_squared_error: 3.1326 - y2_output_root_mean_squared_error: 3.8461 - val_loss: 22.9386 - val_y1_output_loss: 8.7038 - val_y2_output_loss: 13.6430 - val_y1_output_root_mean_squared_error: 2.9888 - val_y2_output_root_mean_squared_error: 3.7425
# Epoch 5/500
# 614/614 [==============================] - 0s 139us/sample - loss: 25.9194 - y1_output_loss: 9.1616 - y2_output_loss: 16.5525 - y1_output_root_mean_squared_error: 3.0390 - y2_output_root_mean_squared_error: 4.0846 - val_loss: 19.5384 - val_y1_output_loss: 8.6854 - val_y2_output_loss: 11.4243 - val_y1_output_root_mean_squared_error: 2.9508 - val_y2_output_root_mean_squared_error: 3.2911
# Epoch 6/500
# 614/614 [==============================] - 0s 137us/sample - loss: 21.7731 - y1_output_loss: 8.7285 - y2_output_loss: 13.0068 - y1_output_root_mean_squared_error: 2.9456 - y2_output_root_mean_squared_error: 3.6189 - val_loss: 21.7286 - val_y1_output_loss: 10.0895 - val_y2_output_loss: 11.2269 - val_y1_output_root_mean_squared_error: 3.2263 - val_y2_output_root_mean_squared_error: 3.3645
# Epoch 7/500
# 614/614 [==============================] - 0s 134us/sample - loss: 24.7714 - y1_output_loss: 9.2712 - y2_output_loss: 15.4581 - y1_output_root_mean_squared_error: 3.0463 - y2_output_root_mean_squared_error: 3.9359 - val_loss: 39.7904 - val_y1_output_loss: 14.5674 - val_y2_output_loss: 26.8146 - val_y1_output_root_mean_squared_error: 3.7991 - val_y2_output_root_mean_squared_error: 5.0356
# Epoch 8/500
# 614/614 [==============================] - 0s 128us/sample - loss: 23.5117 - y1_output_loss: 8.9920 - y2_output_loss: 14.3234 - y1_output_root_mean_squared_error: 3.0099 - y2_output_root_mean_squared_error: 3.8016 - val_loss: 18.5948 - val_y1_output_loss: 7.9192 - val_y2_output_loss: 11.5013 - val_y1_output_root_mean_squared_error: 2.8161 - val_y2_output_root_mean_squared_error: 3.2657
# Epoch 9/500
# 614/614 [==============================] - 0s 143us/sample - loss: 23.3745 - y1_output_loss: 8.8460 - y2_output_loss: 14.4471 - y1_output_root_mean_squared_error: 2.9744 - y2_output_root_mean_squared_error: 3.8115 - val_loss: 30.5959 - val_y1_output_loss: 10.5461 - val_y2_output_loss: 21.7564 - val_y1_output_root_mean_squared_error: 3.2227 - val_y2_output_root_mean_squared_error: 4.4956
# Epoch 10/500
# 614/614 [==============================] - 0s 142us/sample - loss: 22.3927 - y1_output_loss: 8.4489 - y2_output_loss: 13.9579 - y1_output_root_mean_squared_error: 2.9111 - y2_output_root_mean_squared_error: 3.7307 - val_loss: 17.6801 - val_y1_output_loss: 8.1691 - val_y2_output_loss: 9.6799 - val_y1_output_root_mean_squared_error: 2.8698 - val_y2_output_root_mean_squared_error: 3.0732
# Epoch 11/500
# 614/614 [==============================] - 0s 142us/sample - loss: 20.5562 - y1_output_loss: 8.2273 - y2_output_loss: 12.1608 - y1_output_root_mean_squared_error: 2.8809 - y2_output_root_mean_squared_error: 3.5009 - val_loss: 21.5702 - val_y1_output_loss: 9.1965 - val_y2_output_loss: 13.5072 - val_y1_output_root_mean_squared_error: 3.0140 - val_y2_output_root_mean_squared_error: 3.5335
# Epoch 12/500
# 614/614 [==============================] - 0s 135us/sample - loss: 21.2683 - y1_output_loss: 8.2109 - y2_output_loss: 13.1256 - y1_output_root_mean_squared_error: 2.8608 - y2_output_root_mean_squared_error: 3.6172 - val_loss: 23.4931 - val_y1_output_loss: 8.8315 - val_y2_output_loss: 15.7145 - val_y1_output_root_mean_squared_error: 2.9728 - val_y2_output_root_mean_squared_error: 3.8282
# Epoch 13/500
# 614/614 [==============================] - 0s 142us/sample - loss: 18.7508 - y1_output_loss: 7.5923 - y2_output_loss: 11.3993 - y1_output_root_mean_squared_error: 2.7357 - y2_output_root_mean_squared_error: 3.3566 - val_loss: 18.0371 - val_y1_output_loss: 7.3654 - val_y2_output_loss: 10.5338 - val_y1_output_root_mean_squared_error: 2.7431 - val_y2_output_root_mean_squared_error: 3.2423
# Epoch 14/500
# 614/614 [==============================] - 0s 143us/sample - loss: 20.3365 - y1_output_loss: 7.9270 - y2_output_loss: 12.5515 - y1_output_root_mean_squared_error: 2.7938 - y2_output_root_mean_squared_error: 3.5399 - val_loss: 30.2276 - val_y1_output_loss: 8.4877 - val_y2_output_loss: 23.1475 - val_y1_output_root_mean_squared_error: 2.9132 - val_y2_output_root_mean_squared_error: 4.6627
# Epoch 15/500
# 614/614 [==============================] - 0s 147us/sample - loss: 27.1242 - y1_output_loss: 9.2738 - y2_output_loss: 17.6114 - y1_output_root_mean_squared_error: 3.0582 - y2_output_root_mean_squared_error: 4.2156 - val_loss: 15.8713 - val_y1_output_loss: 6.6796 - val_y2_output_loss: 9.5466 - val_y1_output_root_mean_squared_error: 2.6128 - val_y2_output_root_mean_squared_error: 3.0074
# Epoch 16/500
# 614/614 [==============================] - 0s 132us/sample - loss: 19.3879 - y1_output_loss: 7.5847 - y2_output_loss: 11.9108 - y1_output_root_mean_squared_error: 2.7328 - y2_output_root_mean_squared_error: 3.4525 - val_loss: 14.4490 - val_y1_output_loss: 6.3229 - val_y2_output_loss: 8.1960 - val_y1_output_root_mean_squared_error: 2.5437 - val_y2_output_root_mean_squared_error: 2.8247
# Epoch 17/500
# 614/614 [==============================] - 0s 128us/sample - loss: 17.9227 - y1_output_loss: 7.0854 - y2_output_loss: 10.6674 - y1_output_root_mean_squared_error: 2.6745 - y2_output_root_mean_squared_error: 3.2818 - val_loss: 15.9759 - val_y1_output_loss: 6.4410 - val_y2_output_loss: 9.9948 - val_y1_output_root_mean_squared_error: 2.5599 - val_y2_output_root_mean_squared_error: 3.0697
# Epoch 18/500
# 614/614 [==============================] - 0s 130us/sample - loss: 17.9267 - y1_output_loss: 6.7382 - y2_output_loss: 11.2249 - y1_output_root_mean_squared_error: 2.5978 - y2_output_root_mean_squared_error: 3.3434 - val_loss: 13.2234 - val_y1_output_loss: 5.8801 - val_y2_output_loss: 7.4731 - val_y1_output_root_mean_squared_error: 2.4354 - val_y2_output_root_mean_squared_error: 2.7004
# Epoch 19/500
# 614/614 [==============================] - 0s 132us/sample - loss: 15.9128 - y1_output_loss: 6.3363 - y2_output_loss: 9.5743 - y1_output_root_mean_squared_error: 2.5144 - y2_output_root_mean_squared_error: 3.0969 - val_loss: 31.1811 - val_y1_output_loss: 9.8366 - val_y2_output_loss: 22.9951 - val_y1_output_root_mean_squared_error: 3.1117 - val_y2_output_root_mean_squared_error: 4.6366
# Epoch 20/500
# 614/614 [==============================] - 0s 128us/sample - loss: 15.2396 - y1_output_loss: 6.3334 - y2_output_loss: 9.2891 - y1_output_root_mean_squared_error: 2.4686 - y2_output_root_mean_squared_error: 3.0242 - val_loss: 48.8963 - val_y1_output_loss: 18.6773 - val_y2_output_loss: 31.6284 - val_y1_output_root_mean_squared_error: 4.3128 - val_y2_output_root_mean_squared_error: 5.5042
# Epoch 21/500
# 614/614 [==============================] - 0s 134us/sample - loss: 16.4689 - y1_output_loss: 6.4842 - y2_output_loss: 9.8831 - y1_output_root_mean_squared_error: 2.5571 - y2_output_root_mean_squared_error: 3.1512 - val_loss: 13.0976 - val_y1_output_loss: 5.3802 - val_y2_output_loss: 7.9671 - val_y1_output_root_mean_squared_error: 2.3424 - val_y2_output_root_mean_squared_error: 2.7588
# Epoch 22/500
# 614/614 [==============================] - 0s 130us/sample - loss: 14.5568 - y1_output_loss: 5.5617 - y2_output_loss: 9.1395 - y1_output_root_mean_squared_error: 2.3361 - y2_output_root_mean_squared_error: 3.0165 - val_loss: 22.6755 - val_y1_output_loss: 6.3841 - val_y2_output_loss: 17.3885 - val_y1_output_root_mean_squared_error: 2.5274 - val_y2_output_root_mean_squared_error: 4.0358
# Epoch 23/500
# 614/614 [==============================] - 0s 132us/sample - loss: 13.8854 - y1_output_loss: 5.2335 - y2_output_loss: 8.5824 - y1_output_root_mean_squared_error: 2.2899 - y2_output_root_mean_squared_error: 2.9397 - val_loss: 10.4672 - val_y1_output_loss: 4.1126 - val_y2_output_loss: 6.6716 - val_y1_output_root_mean_squared_error: 2.0542 - val_y2_output_root_mean_squared_error: 2.4995
# Epoch 24/500
# 614/614 [==============================] - 0s 130us/sample - loss: 15.2674 - y1_output_loss: 5.6482 - y2_output_loss: 9.5683 - y1_output_root_mean_squared_error: 2.3765 - y2_output_root_mean_squared_error: 3.1016 - val_loss: 18.2610 - val_y1_output_loss: 5.9511 - val_y2_output_loss: 13.2034 - val_y1_output_root_mean_squared_error: 2.4403 - val_y2_output_root_mean_squared_error: 3.5080
# Epoch 25/500
# 614/614 [==============================] - 0s 130us/sample - loss: 13.3303 - y1_output_loss: 5.3919 - y2_output_loss: 8.0360 - y1_output_root_mean_squared_error: 2.3200 - y2_output_root_mean_squared_error: 2.8192 - val_loss: 15.8916 - val_y1_output_loss: 4.0132 - val_y2_output_loss: 11.3353 - val_y1_output_root_mean_squared_error: 2.0405 - val_y2_output_root_mean_squared_error: 3.4246
# Epoch 26/500
# 614/614 [==============================] - 0s 131us/sample - loss: 12.5757 - y1_output_loss: 4.7675 - y2_output_loss: 7.6968 - y1_output_root_mean_squared_error: 2.1927 - y2_output_root_mean_squared_error: 2.7871 - val_loss: 24.1769 - val_y1_output_loss: 6.3953 - val_y2_output_loss: 16.9982 - val_y1_output_root_mean_squared_error: 2.5675 - val_y2_output_root_mean_squared_error: 4.1934
# Epoch 27/500
# 614/614 [==============================] - 0s 128us/sample - loss: 15.5416 - y1_output_loss: 5.2682 - y2_output_loss: 10.1631 - y1_output_root_mean_squared_error: 2.3024 - y2_output_root_mean_squared_error: 3.2001 - val_loss: 9.9647 - val_y1_output_loss: 3.7513 - val_y2_output_loss: 6.4415 - val_y1_output_root_mean_squared_error: 1.9648 - val_y2_output_root_mean_squared_error: 2.4707
# Epoch 28/500
# 614/614 [==============================] - 0s 136us/sample - loss: 13.7510 - y1_output_loss: 4.8583 - y2_output_loss: 8.9128 - y1_output_root_mean_squared_error: 2.1981 - y2_output_root_mean_squared_error: 2.9865 - val_loss: 14.4786 - val_y1_output_loss: 4.7755 - val_y2_output_loss: 10.3929 - val_y1_output_root_mean_squared_error: 2.1861 - val_y2_output_root_mean_squared_error: 3.1144
# Epoch 29/500
# 614/614 [==============================] - 0s 129us/sample - loss: 11.7191 - y1_output_loss: 4.2484 - y2_output_loss: 7.4016 - y1_output_root_mean_squared_error: 2.0688 - y2_output_root_mean_squared_error: 2.7275 - val_loss: 10.2189 - val_y1_output_loss: 4.1852 - val_y2_output_loss: 6.1173 - val_y1_output_root_mean_squared_error: 2.0740 - val_y2_output_root_mean_squared_error: 2.4326
# Epoch 30/500
# 614/614 [==============================] - 0s 128us/sample - loss: 9.8800 - y1_output_loss: 3.6936 - y2_output_loss: 6.1704 - y1_output_root_mean_squared_error: 1.9116 - y2_output_root_mean_squared_error: 2.4952 - val_loss: 15.0755 - val_y1_output_loss: 6.8206 - val_y2_output_loss: 8.4836 - val_y1_output_root_mean_squared_error: 2.6275 - val_y2_output_root_mean_squared_error: 2.8586
# Epoch 31/500
# 614/614 [==============================] - 0s 130us/sample - loss: 11.0155 - y1_output_loss: 3.9755 - y2_output_loss: 6.9691 - y1_output_root_mean_squared_error: 2.0029 - y2_output_root_mean_squared_error: 2.6465 - val_loss: 10.7771 - val_y1_output_loss: 3.1581 - val_y2_output_loss: 7.2881 - val_y1_output_root_mean_squared_error: 1.8073 - val_y2_output_root_mean_squared_error: 2.7406
# Epoch 32/500
# 614/614 [==============================] - 0s 143us/sample - loss: 12.6939 - y1_output_loss: 4.0328 - y2_output_loss: 8.5651 - y1_output_root_mean_squared_error: 2.0162 - y2_output_root_mean_squared_error: 2.9375 - val_loss: 9.5840 - val_y1_output_loss: 3.2004 - val_y2_output_loss: 6.6258 - val_y1_output_root_mean_squared_error: 1.8169 - val_y2_output_root_mean_squared_error: 2.5065
# Epoch 33/500
# 614/614 [==============================] - 0s 133us/sample - loss: 9.1869 - y1_output_loss: 3.3828 - y2_output_loss: 5.9862 - y1_output_root_mean_squared_error: 1.8182 - y2_output_root_mean_squared_error: 2.4251 - val_loss: 31.7254 - val_y1_output_loss: 10.5082 - val_y2_output_loss: 22.4167 - val_y1_output_root_mean_squared_error: 3.2301 - val_y2_output_root_mean_squared_error: 4.6143
# Epoch 34/500
# 614/614 [==============================] - 0s 140us/sample - loss: 9.5811 - y1_output_loss: 3.3896 - y2_output_loss: 6.2884 - y1_output_root_mean_squared_error: 1.8378 - y2_output_root_mean_squared_error: 2.4907 - val_loss: 10.8507 - val_y1_output_loss: 2.8796 - val_y2_output_loss: 7.6963 - val_y1_output_root_mean_squared_error: 1.7189 - val_y2_output_root_mean_squared_error: 2.8100
# Epoch 35/500
# 614/614 [==============================] - 0s 132us/sample - loss: 10.4498 - y1_output_loss: 3.4908 - y2_output_loss: 6.8873 - y1_output_root_mean_squared_error: 1.8772 - y2_output_root_mean_squared_error: 2.6317 - val_loss: 14.6301 - val_y1_output_loss: 3.0919 - val_y2_output_loss: 11.1284 - val_y1_output_root_mean_squared_error: 1.7710 - val_y2_output_root_mean_squared_error: 3.3902
# Epoch 36/500
# 614/614 [==============================] - 0s 130us/sample - loss: 11.3910 - y1_output_loss: 3.7319 - y2_output_loss: 7.6725 - y1_output_root_mean_squared_error: 1.9321 - y2_output_root_mean_squared_error: 2.7673 - val_loss: 7.9149 - val_y1_output_loss: 3.0186 - val_y2_output_loss: 5.1192 - val_y1_output_root_mean_squared_error: 1.7421 - val_y2_output_root_mean_squared_error: 2.2091
# Epoch 37/500
# 614/614 [==============================] - 0s 129us/sample - loss: 8.7686 - y1_output_loss: 2.9598 - y2_output_loss: 5.8271 - y1_output_root_mean_squared_error: 1.7199 - y2_output_root_mean_squared_error: 2.4105 - val_loss: 12.1702 - val_y1_output_loss: 3.5761 - val_y2_output_loss: 8.2265 - val_y1_output_root_mean_squared_error: 1.9155 - val_y2_output_root_mean_squared_error: 2.9156
# Epoch 38/500
# 614/614 [==============================] - 0s 129us/sample - loss: 10.7500 - y1_output_loss: 3.5823 - y2_output_loss: 7.1689 - y1_output_root_mean_squared_error: 1.8989 - y2_output_root_mean_squared_error: 2.6729 - val_loss: 19.8559 - val_y1_output_loss: 4.2412 - val_y2_output_loss: 14.9772 - val_y1_output_root_mean_squared_error: 2.0862 - val_y2_output_root_mean_squared_error: 3.9375
# Epoch 39/500
# 614/614 [==============================] - 0s 139us/sample - loss: 10.5980 - y1_output_loss: 3.3704 - y2_output_loss: 7.1776 - y1_output_root_mean_squared_error: 1.8319 - y2_output_root_mean_squared_error: 2.6911 - val_loss: 10.3536 - val_y1_output_loss: 3.8612 - val_y2_output_loss: 6.9694 - val_y1_output_root_mean_squared_error: 1.9576 - val_y2_output_root_mean_squared_error: 2.5537
# Epoch 40/500
# 614/614 [==============================] - 0s 129us/sample - loss: 8.2059 - y1_output_loss: 2.7806 - y2_output_loss: 5.3968 - y1_output_root_mean_squared_error: 1.6703 - y2_output_root_mean_squared_error: 2.3272 - val_loss: 12.0275 - val_y1_output_loss: 3.7232 - val_y2_output_loss: 8.9617 - val_y1_output_root_mean_squared_error: 1.9238 - val_y2_output_root_mean_squared_error: 2.8855
# Epoch 41/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.7779 - y1_output_loss: 2.5966 - y2_output_loss: 5.2392 - y1_output_root_mean_squared_error: 1.6080 - y2_output_root_mean_squared_error: 2.2787 - val_loss: 20.4887 - val_y1_output_loss: 4.3086 - val_y2_output_loss: 15.5546 - val_y1_output_root_mean_squared_error: 2.0966 - val_y2_output_root_mean_squared_error: 4.0116
# Epoch 42/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.9321 - y1_output_loss: 3.0072 - y2_output_loss: 5.9104 - y1_output_root_mean_squared_error: 1.7282 - y2_output_root_mean_squared_error: 2.4383 - val_loss: 13.7646 - val_y1_output_loss: 4.8039 - val_y2_output_loss: 9.4172 - val_y1_output_root_mean_squared_error: 2.1922 - val_y2_output_root_mean_squared_error: 2.9931
# Epoch 43/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.2858 - y1_output_loss: 3.0957 - y2_output_loss: 6.1113 - y1_output_root_mean_squared_error: 1.7672 - y2_output_root_mean_squared_error: 2.4825 - val_loss: 7.1850 - val_y1_output_loss: 2.1182 - val_y2_output_loss: 4.9474 - val_y1_output_root_mean_squared_error: 1.4781 - val_y2_output_root_mean_squared_error: 2.2361
# Epoch 44/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.9194 - y1_output_loss: 2.1888 - y2_output_loss: 4.7717 - y1_output_root_mean_squared_error: 1.4785 - y2_output_root_mean_squared_error: 2.1757 - val_loss: 11.7334 - val_y1_output_loss: 4.6301 - val_y2_output_loss: 7.3963 - val_y1_output_root_mean_squared_error: 2.1578 - val_y2_output_root_mean_squared_error: 2.6603
# Epoch 45/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.0528 - y1_output_loss: 2.0675 - y2_output_loss: 4.0817 - y1_output_root_mean_squared_error: 1.4352 - y2_output_root_mean_squared_error: 1.9982 - val_loss: 21.6443 - val_y1_output_loss: 5.6644 - val_y2_output_loss: 15.2868 - val_y1_output_root_mean_squared_error: 2.4100 - val_y2_output_root_mean_squared_error: 3.9795
# Epoch 46/500
# 614/614 [==============================] - 0s 145us/sample - loss: 7.3966 - y1_output_loss: 2.1430 - y2_output_loss: 5.1892 - y1_output_root_mean_squared_error: 1.4703 - y2_output_root_mean_squared_error: 2.2880 - val_loss: 8.1207 - val_y1_output_loss: 2.8077 - val_y2_output_loss: 5.5147 - val_y1_output_root_mean_squared_error: 1.6673 - val_y2_output_root_mean_squared_error: 2.3110
# Epoch 47/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.1713 - y1_output_loss: 2.1874 - y2_output_loss: 4.9383 - y1_output_root_mean_squared_error: 1.4813 - y2_output_root_mean_squared_error: 2.2309 - val_loss: 10.0912 - val_y1_output_loss: 2.6240 - val_y2_output_loss: 7.1945 - val_y1_output_root_mean_squared_error: 1.6327 - val_y2_output_root_mean_squared_error: 2.7250
# Epoch 48/500
# 614/614 [==============================] - 0s 135us/sample - loss: 8.1017 - y1_output_loss: 2.4969 - y2_output_loss: 5.6668 - y1_output_root_mean_squared_error: 1.5780 - y2_output_root_mean_squared_error: 2.3689 - val_loss: 10.5656 - val_y1_output_loss: 2.3920 - val_y2_output_loss: 7.8564 - val_y1_output_root_mean_squared_error: 1.5644 - val_y2_output_root_mean_squared_error: 2.8492
# Epoch 49/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.7000 - y1_output_loss: 2.2472 - y2_output_loss: 5.3870 - y1_output_root_mean_squared_error: 1.5046 - y2_output_root_mean_squared_error: 2.3316 - val_loss: 9.2858 - val_y1_output_loss: 3.1641 - val_y2_output_loss: 6.3742 - val_y1_output_root_mean_squared_error: 1.7717 - val_y2_output_root_mean_squared_error: 2.4793
# Epoch 50/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.7334 - y1_output_loss: 2.1838 - y2_output_loss: 4.5491 - y1_output_root_mean_squared_error: 1.4762 - y2_output_root_mean_squared_error: 2.1341 - val_loss: 11.1040 - val_y1_output_loss: 3.7472 - val_y2_output_loss: 7.0697 - val_y1_output_root_mean_squared_error: 1.9441 - val_y2_output_root_mean_squared_error: 2.7064
# Epoch 51/500
# 614/614 [==============================] - 0s 133us/sample - loss: 13.9461 - y1_output_loss: 4.3433 - y2_output_loss: 9.5672 - y1_output_root_mean_squared_error: 2.0823 - y2_output_root_mean_squared_error: 3.1000 - val_loss: 7.8375 - val_y1_output_loss: 2.2406 - val_y2_output_loss: 5.4340 - val_y1_output_root_mean_squared_error: 1.5112 - val_y2_output_root_mean_squared_error: 2.3566
# Epoch 52/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.5025 - y1_output_loss: 2.3539 - y2_output_loss: 5.2594 - y1_output_root_mean_squared_error: 1.5140 - y2_output_root_mean_squared_error: 2.2826 - val_loss: 13.6021 - val_y1_output_loss: 3.5028 - val_y2_output_loss: 10.8698 - val_y1_output_root_mean_squared_error: 1.8641 - val_y2_output_root_mean_squared_error: 3.1824
# Epoch 53/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.3849 - y1_output_loss: 2.4320 - y2_output_loss: 4.9312 - y1_output_root_mean_squared_error: 1.5560 - y2_output_root_mean_squared_error: 2.2279 - val_loss: 7.5049 - val_y1_output_loss: 2.4231 - val_y2_output_loss: 5.1100 - val_y1_output_root_mean_squared_error: 1.5587 - val_y2_output_root_mean_squared_error: 2.2529
# Epoch 54/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.1000 - y1_output_loss: 1.9626 - y2_output_loss: 4.1276 - y1_output_root_mean_squared_error: 1.4048 - y2_output_root_mean_squared_error: 2.0314 - val_loss: 6.4930 - val_y1_output_loss: 2.0424 - val_y2_output_loss: 4.4439 - val_y1_output_root_mean_squared_error: 1.4343 - val_y2_output_root_mean_squared_error: 2.1061
# Epoch 55/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.8489 - y1_output_loss: 2.2838 - y2_output_loss: 5.5167 - y1_output_root_mean_squared_error: 1.5133 - y2_output_root_mean_squared_error: 2.3577 - val_loss: 9.4886 - val_y1_output_loss: 3.3457 - val_y2_output_loss: 6.4936 - val_y1_output_root_mean_squared_error: 1.8241 - val_y2_output_root_mean_squared_error: 2.4822
# Epoch 56/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.3977 - y1_output_loss: 2.2816 - y2_output_loss: 5.1212 - y1_output_root_mean_squared_error: 1.5172 - y2_output_root_mean_squared_error: 2.2573 - val_loss: 11.4172 - val_y1_output_loss: 2.1397 - val_y2_output_loss: 8.9703 - val_y1_output_root_mean_squared_error: 1.4634 - val_y2_output_root_mean_squared_error: 3.0456
# Epoch 57/500
# 614/614 [==============================] - 0s 128us/sample - loss: 8.6326 - y1_output_loss: 2.6263 - y2_output_loss: 5.9643 - y1_output_root_mean_squared_error: 1.6194 - y2_output_root_mean_squared_error: 2.4516 - val_loss: 6.0097 - val_y1_output_loss: 1.9556 - val_y2_output_loss: 4.2431 - val_y1_output_root_mean_squared_error: 1.3932 - val_y2_output_root_mean_squared_error: 2.0171
# Epoch 58/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.4042 - y1_output_loss: 1.7178 - y2_output_loss: 3.6495 - y1_output_root_mean_squared_error: 1.3167 - y2_output_root_mean_squared_error: 1.9159 - val_loss: 7.3847 - val_y1_output_loss: 2.2133 - val_y2_output_loss: 5.0720 - val_y1_output_root_mean_squared_error: 1.4891 - val_y2_output_root_mean_squared_error: 2.2732
# Epoch 59/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.1067 - y1_output_loss: 1.8251 - y2_output_loss: 4.2467 - y1_output_root_mean_squared_error: 1.3560 - y2_output_root_mean_squared_error: 2.0659 - val_loss: 8.8935 - val_y1_output_loss: 3.0438 - val_y2_output_loss: 6.2250 - val_y1_output_root_mean_squared_error: 1.7323 - val_y2_output_root_mean_squared_error: 2.4275
# Epoch 60/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.2576 - y1_output_loss: 1.6438 - y2_output_loss: 3.5798 - y1_output_root_mean_squared_error: 1.2851 - y2_output_root_mean_squared_error: 1.8990 - val_loss: 8.0426 - val_y1_output_loss: 2.2815 - val_y2_output_loss: 6.0584 - val_y1_output_root_mean_squared_error: 1.5152 - val_y2_output_root_mean_squared_error: 2.3972
# Epoch 61/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.0821 - y1_output_loss: 1.7801 - y2_output_loss: 4.2731 - y1_output_root_mean_squared_error: 1.3360 - y2_output_root_mean_squared_error: 2.0730 - val_loss: 7.3958 - val_y1_output_loss: 2.1140 - val_y2_output_loss: 5.6160 - val_y1_output_root_mean_squared_error: 1.4434 - val_y2_output_root_mean_squared_error: 2.3049
# Epoch 62/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.0953 - y1_output_loss: 1.9200 - y2_output_loss: 4.1422 - y1_output_root_mean_squared_error: 1.3869 - y2_output_root_mean_squared_error: 2.0425 - val_loss: 7.1804 - val_y1_output_loss: 2.0912 - val_y2_output_loss: 5.4642 - val_y1_output_root_mean_squared_error: 1.4429 - val_y2_output_root_mean_squared_error: 2.2580
# Epoch 63/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.2554 - y1_output_loss: 1.8370 - y2_output_loss: 4.3822 - y1_output_root_mean_squared_error: 1.3575 - y2_output_root_mean_squared_error: 2.1006 - val_loss: 7.6685 - val_y1_output_loss: 2.7206 - val_y2_output_loss: 5.2076 - val_y1_output_root_mean_squared_error: 1.6460 - val_y2_output_root_mean_squared_error: 2.2269
# Epoch 64/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.3301 - y1_output_loss: 2.1669 - y2_output_loss: 5.0972 - y1_output_root_mean_squared_error: 1.4784 - y2_output_root_mean_squared_error: 2.2681 - val_loss: 6.2805 - val_y1_output_loss: 2.0076 - val_y2_output_loss: 4.5676 - val_y1_output_root_mean_squared_error: 1.4086 - val_y2_output_root_mean_squared_error: 2.0727
# Epoch 65/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.2406 - y1_output_loss: 1.7523 - y2_output_loss: 4.4905 - y1_output_root_mean_squared_error: 1.3285 - y2_output_root_mean_squared_error: 2.1156 - val_loss: 6.6138 - val_y1_output_loss: 1.9378 - val_y2_output_loss: 4.6438 - val_y1_output_root_mean_squared_error: 1.3831 - val_y2_output_root_mean_squared_error: 2.1681
# Epoch 66/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.8306 - y1_output_loss: 1.8340 - y2_output_loss: 4.9517 - y1_output_root_mean_squared_error: 1.3576 - y2_output_root_mean_squared_error: 2.2333 - val_loss: 7.7555 - val_y1_output_loss: 2.4831 - val_y2_output_loss: 5.4134 - val_y1_output_root_mean_squared_error: 1.5502 - val_y2_output_root_mean_squared_error: 2.3135
# Epoch 67/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.6544 - y1_output_loss: 1.3676 - y2_output_loss: 3.2628 - y1_output_root_mean_squared_error: 1.1722 - y2_output_root_mean_squared_error: 1.8111 - val_loss: 9.8494 - val_y1_output_loss: 2.8327 - val_y2_output_loss: 6.7936 - val_y1_output_root_mean_squared_error: 1.6881 - val_y2_output_root_mean_squared_error: 2.6457
# Epoch 68/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.0321 - y1_output_loss: 1.4889 - y2_output_loss: 3.5049 - y1_output_root_mean_squared_error: 1.2241 - y2_output_root_mean_squared_error: 1.8798 - val_loss: 7.4376 - val_y1_output_loss: 2.5649 - val_y2_output_loss: 5.1066 - val_y1_output_root_mean_squared_error: 1.5750 - val_y2_output_root_mean_squared_error: 2.2264
# Epoch 69/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.8414 - y1_output_loss: 1.3147 - y2_output_loss: 3.4941 - y1_output_root_mean_squared_error: 1.1513 - y2_output_root_mean_squared_error: 1.8751 - val_loss: 6.9411 - val_y1_output_loss: 2.1977 - val_y2_output_loss: 4.8916 - val_y1_output_root_mean_squared_error: 1.4825 - val_y2_output_root_mean_squared_error: 2.1779
# Epoch 70/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.6631 - y1_output_loss: 1.2762 - y2_output_loss: 3.3936 - y1_output_root_mean_squared_error: 1.1174 - y2_output_root_mean_squared_error: 1.8478 - val_loss: 5.4976 - val_y1_output_loss: 1.6775 - val_y2_output_loss: 3.7374 - val_y1_output_root_mean_squared_error: 1.2941 - val_y2_output_root_mean_squared_error: 1.9552
# Epoch 71/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.3171 - y1_output_loss: 1.1848 - y2_output_loss: 3.1806 - y1_output_root_mean_squared_error: 1.0870 - y2_output_root_mean_squared_error: 1.7707 - val_loss: 18.1587 - val_y1_output_loss: 4.0318 - val_y2_output_loss: 13.6674 - val_y1_output_root_mean_squared_error: 2.0131 - val_y2_output_root_mean_squared_error: 3.7558
# Epoch 72/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.3389 - y1_output_loss: 1.4946 - y2_output_loss: 3.8619 - y1_output_root_mean_squared_error: 1.2120 - y2_output_root_mean_squared_error: 1.9672 - val_loss: 30.6680 - val_y1_output_loss: 11.2847 - val_y2_output_loss: 18.5373 - val_y1_output_root_mean_squared_error: 3.3890 - val_y2_output_root_mean_squared_error: 4.3798
# Epoch 73/500
# 614/614 [==============================] - 0s 135us/sample - loss: 9.4731 - y1_output_loss: 2.9412 - y2_output_loss: 6.4636 - y1_output_root_mean_squared_error: 1.7200 - y2_output_root_mean_squared_error: 2.5524 - val_loss: 5.4591 - val_y1_output_loss: 1.6019 - val_y2_output_loss: 3.9465 - val_y1_output_root_mean_squared_error: 1.2841 - val_y2_output_root_mean_squared_error: 1.9520
# Epoch 74/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.1171 - y1_output_loss: 1.2137 - y2_output_loss: 3.0009 - y1_output_root_mean_squared_error: 1.0963 - y2_output_root_mean_squared_error: 1.7074 - val_loss: 18.1205 - val_y1_output_loss: 4.1012 - val_y2_output_loss: 14.8123 - val_y1_output_root_mean_squared_error: 2.0217 - val_y2_output_root_mean_squared_error: 3.7461
# Epoch 75/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.8530 - y1_output_loss: 1.0610 - y2_output_loss: 2.7895 - y1_output_root_mean_squared_error: 1.0309 - y2_output_root_mean_squared_error: 1.6704 - val_loss: 9.7812 - val_y1_output_loss: 2.5558 - val_y2_output_loss: 6.9887 - val_y1_output_root_mean_squared_error: 1.6036 - val_y2_output_root_mean_squared_error: 2.6851
# Epoch 76/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.5686 - y1_output_loss: 1.8251 - y2_output_loss: 4.7079 - y1_output_root_mean_squared_error: 1.3571 - y2_output_root_mean_squared_error: 2.1741 - val_loss: 6.2500 - val_y1_output_loss: 1.2928 - val_y2_output_loss: 4.7703 - val_y1_output_root_mean_squared_error: 1.1441 - val_y2_output_root_mean_squared_error: 2.2228
# Epoch 77/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.0051 - y1_output_loss: 1.0834 - y2_output_loss: 2.9251 - y1_output_root_mean_squared_error: 1.0394 - y2_output_root_mean_squared_error: 1.7102 - val_loss: 5.7004 - val_y1_output_loss: 1.8291 - val_y2_output_loss: 3.9325 - val_y1_output_root_mean_squared_error: 1.3715 - val_y2_output_root_mean_squared_error: 1.9543
# Epoch 78/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.7836 - y1_output_loss: 1.1079 - y2_output_loss: 2.6787 - y1_output_root_mean_squared_error: 1.0537 - y2_output_root_mean_squared_error: 1.6350 - val_loss: 12.1502 - val_y1_output_loss: 3.6789 - val_y2_output_loss: 8.9216 - val_y1_output_root_mean_squared_error: 1.9263 - val_y2_output_root_mean_squared_error: 2.9051
# Epoch 79/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.5213 - y1_output_loss: 0.9009 - y2_output_loss: 2.6045 - y1_output_root_mean_squared_error: 0.9507 - y2_output_root_mean_squared_error: 1.6179 - val_loss: 4.8572 - val_y1_output_loss: 1.5350 - val_y2_output_loss: 3.3921 - val_y1_output_root_mean_squared_error: 1.2354 - val_y2_output_root_mean_squared_error: 1.8251
# Epoch 80/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.7024 - y1_output_loss: 0.8993 - y2_output_loss: 2.7737 - y1_output_root_mean_squared_error: 0.9506 - y2_output_root_mean_squared_error: 1.6729 - val_loss: 3.5268 - val_y1_output_loss: 0.9207 - val_y2_output_loss: 2.6751 - val_y1_output_root_mean_squared_error: 0.9598 - val_y2_output_root_mean_squared_error: 1.6142
# Epoch 81/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.1434 - y1_output_loss: 0.9773 - y2_output_loss: 3.1483 - y1_output_root_mean_squared_error: 0.9917 - y2_output_root_mean_squared_error: 1.7776 - val_loss: 5.6122 - val_y1_output_loss: 1.1987 - val_y2_output_loss: 4.2564 - val_y1_output_root_mean_squared_error: 1.0999 - val_y2_output_root_mean_squared_error: 2.0982
# Epoch 82/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.0876 - y1_output_loss: 0.7742 - y2_output_loss: 2.3279 - y1_output_root_mean_squared_error: 0.8791 - y2_output_root_mean_squared_error: 1.5214 - val_loss: 9.1392 - val_y1_output_loss: 1.2966 - val_y2_output_loss: 7.5645 - val_y1_output_root_mean_squared_error: 1.1433 - val_y2_output_root_mean_squared_error: 2.7986
# Epoch 83/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.7787 - y1_output_loss: 1.3105 - y2_output_loss: 3.4297 - y1_output_root_mean_squared_error: 1.1481 - y2_output_root_mean_squared_error: 1.8602 - val_loss: 4.6585 - val_y1_output_loss: 1.0971 - val_y2_output_loss: 3.6494 - val_y1_output_root_mean_squared_error: 1.0506 - val_y2_output_root_mean_squared_error: 1.8854
# Epoch 84/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.2171 - y1_output_loss: 0.8748 - y2_output_loss: 2.3496 - y1_output_root_mean_squared_error: 0.9344 - y2_output_root_mean_squared_error: 1.5310 - val_loss: 3.4085 - val_y1_output_loss: 0.8395 - val_y2_output_loss: 2.6338 - val_y1_output_root_mean_squared_error: 0.9223 - val_y2_output_root_mean_squared_error: 1.5993
# Epoch 85/500
# 614/614 [==============================] - 0s 125us/sample - loss: 3.9470 - y1_output_loss: 0.9153 - y2_output_loss: 3.0083 - y1_output_root_mean_squared_error: 0.9550 - y2_output_root_mean_squared_error: 1.7421 - val_loss: 5.9559 - val_y1_output_loss: 2.0233 - val_y2_output_loss: 4.0428 - val_y1_output_root_mean_squared_error: 1.4381 - val_y2_output_root_mean_squared_error: 1.9718
# Epoch 86/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.9676 - y1_output_loss: 0.9787 - y2_output_loss: 2.9644 - y1_output_root_mean_squared_error: 0.9908 - y2_output_root_mean_squared_error: 1.7280 - val_loss: 4.2622 - val_y1_output_loss: 1.1913 - val_y2_output_loss: 3.0122 - val_y1_output_root_mean_squared_error: 1.1026 - val_y2_output_root_mean_squared_error: 1.7454
# Epoch 87/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.2925 - y1_output_loss: 1.4829 - y2_output_loss: 3.8178 - y1_output_root_mean_squared_error: 1.2228 - y2_output_root_mean_squared_error: 1.9486 - val_loss: 5.5026 - val_y1_output_loss: 0.8244 - val_y2_output_loss: 4.5346 - val_y1_output_root_mean_squared_error: 0.9012 - val_y2_output_root_mean_squared_error: 2.1658
# Epoch 88/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.0032 - y1_output_loss: 0.7601 - y2_output_loss: 2.2251 - y1_output_root_mean_squared_error: 0.8748 - y2_output_root_mean_squared_error: 1.4960 - val_loss: 3.5796 - val_y1_output_loss: 0.9063 - val_y2_output_loss: 2.7397 - val_y1_output_root_mean_squared_error: 0.9568 - val_y2_output_root_mean_squared_error: 1.6322
# Epoch 89/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.2983 - y1_output_loss: 0.8521 - y2_output_loss: 2.4324 - y1_output_root_mean_squared_error: 0.9244 - y2_output_root_mean_squared_error: 1.5633 - val_loss: 4.3327 - val_y1_output_loss: 1.1191 - val_y2_output_loss: 3.1810 - val_y1_output_root_mean_squared_error: 1.0702 - val_y2_output_root_mean_squared_error: 1.7853
# Epoch 90/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.7075 - y1_output_loss: 0.6812 - y2_output_loss: 2.0502 - y1_output_root_mean_squared_error: 0.8273 - y2_output_root_mean_squared_error: 1.4224 - val_loss: 8.2179 - val_y1_output_loss: 1.4135 - val_y2_output_loss: 6.5653 - val_y1_output_root_mean_squared_error: 1.1901 - val_y2_output_root_mean_squared_error: 2.6080
# Epoch 91/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.6445 - y1_output_loss: 0.9283 - y2_output_loss: 2.7040 - y1_output_root_mean_squared_error: 0.9604 - y2_output_root_mean_squared_error: 1.6499 - val_loss: 3.1733 - val_y1_output_loss: 0.8840 - val_y2_output_loss: 2.2876 - val_y1_output_root_mean_squared_error: 0.9554 - val_y2_output_root_mean_squared_error: 1.5035
# Epoch 92/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.6301 - y1_output_loss: 0.7518 - y2_output_loss: 2.8648 - y1_output_root_mean_squared_error: 0.8695 - y2_output_root_mean_squared_error: 1.6953 - val_loss: 4.3868 - val_y1_output_loss: 1.2780 - val_y2_output_loss: 3.0686 - val_y1_output_root_mean_squared_error: 1.1333 - val_y2_output_root_mean_squared_error: 1.7614
# Epoch 93/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.0532 - y1_output_loss: 1.6954 - y2_output_loss: 4.3295 - y1_output_root_mean_squared_error: 1.3050 - y2_output_root_mean_squared_error: 2.0857 - val_loss: 4.4710 - val_y1_output_loss: 1.3116 - val_y2_output_loss: 3.2163 - val_y1_output_root_mean_squared_error: 1.1395 - val_y2_output_root_mean_squared_error: 1.7812
# Epoch 94/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.4335 - y1_output_loss: 0.6565 - y2_output_loss: 1.7747 - y1_output_root_mean_squared_error: 0.8130 - y2_output_root_mean_squared_error: 1.3314 - val_loss: 3.5925 - val_y1_output_loss: 0.7909 - val_y2_output_loss: 2.7457 - val_y1_output_root_mean_squared_error: 0.8914 - val_y2_output_root_mean_squared_error: 1.6727
# Epoch 95/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.7455 - y1_output_loss: 0.7023 - y2_output_loss: 2.0409 - y1_output_root_mean_squared_error: 0.8363 - y2_output_root_mean_squared_error: 1.4305 - val_loss: 3.4836 - val_y1_output_loss: 0.7710 - val_y2_output_loss: 2.6414 - val_y1_output_root_mean_squared_error: 0.8834 - val_y2_output_root_mean_squared_error: 1.6442
# Epoch 96/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.3673 - y1_output_loss: 0.5865 - y2_output_loss: 1.7773 - y1_output_root_mean_squared_error: 0.7641 - y2_output_root_mean_squared_error: 1.3354 - val_loss: 3.5232 - val_y1_output_loss: 0.7216 - val_y2_output_loss: 2.7243 - val_y1_output_root_mean_squared_error: 0.8516 - val_y2_output_root_mean_squared_error: 1.6727
# Epoch 97/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.0090 - y1_output_loss: 1.2822 - y2_output_loss: 3.6984 - y1_output_root_mean_squared_error: 1.1370 - y2_output_root_mean_squared_error: 1.9278 - val_loss: 5.3594 - val_y1_output_loss: 1.6524 - val_y2_output_loss: 3.7795 - val_y1_output_root_mean_squared_error: 1.3066 - val_y2_output_root_mean_squared_error: 1.9110
# Epoch 98/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.9931 - y1_output_loss: 1.3547 - y2_output_loss: 3.5939 - y1_output_root_mean_squared_error: 1.1684 - y2_output_root_mean_squared_error: 1.9047 - val_loss: 3.1251 - val_y1_output_loss: 0.7726 - val_y2_output_loss: 2.4298 - val_y1_output_root_mean_squared_error: 0.8890 - val_y2_output_root_mean_squared_error: 1.5280
# Epoch 99/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.6844 - y1_output_loss: 0.6295 - y2_output_loss: 2.0493 - y1_output_root_mean_squared_error: 0.7906 - y2_output_root_mean_squared_error: 1.4350 - val_loss: 5.6912 - val_y1_output_loss: 1.4913 - val_y2_output_loss: 4.3622 - val_y1_output_root_mean_squared_error: 1.2379 - val_y2_output_root_mean_squared_error: 2.0393
# Epoch 100/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.5942 - y1_output_loss: 0.8749 - y2_output_loss: 2.6871 - y1_output_root_mean_squared_error: 0.9394 - y2_output_root_mean_squared_error: 1.6467 - val_loss: 3.0544 - val_y1_output_loss: 0.7551 - val_y2_output_loss: 2.2974 - val_y1_output_root_mean_squared_error: 0.8780 - val_y2_output_root_mean_squared_error: 1.5111
# Epoch 101/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.0612 - y1_output_loss: 0.7679 - y2_output_loss: 2.2812 - y1_output_root_mean_squared_error: 0.8793 - y2_output_root_mean_squared_error: 1.5126 - val_loss: 2.8981 - val_y1_output_loss: 0.6603 - val_y2_output_loss: 2.3235 - val_y1_output_root_mean_squared_error: 0.8239 - val_y2_output_root_mean_squared_error: 1.4898
# Epoch 102/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.9901 - y1_output_loss: 0.7574 - y2_output_loss: 2.2566 - y1_output_root_mean_squared_error: 0.8633 - y2_output_root_mean_squared_error: 1.4983 - val_loss: 7.4152 - val_y1_output_loss: 3.3244 - val_y2_output_loss: 3.9944 - val_y1_output_root_mean_squared_error: 1.8284 - val_y2_output_root_mean_squared_error: 2.0180
# Epoch 103/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.1096 - y1_output_loss: 0.7599 - y2_output_loss: 2.3222 - y1_output_root_mean_squared_error: 0.8750 - y2_output_root_mean_squared_error: 1.5310 - val_loss: 3.6303 - val_y1_output_loss: 1.0123 - val_y2_output_loss: 2.6293 - val_y1_output_root_mean_squared_error: 1.0171 - val_y2_output_root_mean_squared_error: 1.6111
# Epoch 104/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.4613 - y1_output_loss: 0.6552 - y2_output_loss: 1.7909 - y1_output_root_mean_squared_error: 0.8124 - y2_output_root_mean_squared_error: 1.3421 - val_loss: 3.0166 - val_y1_output_loss: 0.6654 - val_y2_output_loss: 2.4367 - val_y1_output_root_mean_squared_error: 0.8232 - val_y2_output_root_mean_squared_error: 1.5294
# Epoch 105/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.4199 - y1_output_loss: 0.9459 - y2_output_loss: 2.4591 - y1_output_root_mean_squared_error: 0.9717 - y2_output_root_mean_squared_error: 1.5735 - val_loss: 3.0914 - val_y1_output_loss: 0.6665 - val_y2_output_loss: 2.5328 - val_y1_output_root_mean_squared_error: 0.8209 - val_y2_output_root_mean_squared_error: 1.5548
# Epoch 106/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.1402 - y1_output_loss: 0.7145 - y2_output_loss: 2.4208 - y1_output_root_mean_squared_error: 0.8478 - y2_output_root_mean_squared_error: 1.5561 - val_loss: 3.7105 - val_y1_output_loss: 1.1265 - val_y2_output_loss: 2.5462 - val_y1_output_root_mean_squared_error: 1.0719 - val_y2_output_root_mean_squared_error: 1.6005
# Epoch 107/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.9305 - y1_output_loss: 1.2133 - y2_output_loss: 2.6829 - y1_output_root_mean_squared_error: 1.1066 - y2_output_root_mean_squared_error: 1.6450 - val_loss: 3.7043 - val_y1_output_loss: 0.7804 - val_y2_output_loss: 3.1374 - val_y1_output_root_mean_squared_error: 0.8803 - val_y2_output_root_mean_squared_error: 1.7115
# Epoch 108/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.8722 - y1_output_loss: 0.7225 - y2_output_loss: 2.1293 - y1_output_root_mean_squared_error: 0.8509 - y2_output_root_mean_squared_error: 1.4657 - val_loss: 2.7741 - val_y1_output_loss: 0.6525 - val_y2_output_loss: 2.1867 - val_y1_output_root_mean_squared_error: 0.8092 - val_y2_output_root_mean_squared_error: 1.4558
# Epoch 109/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.4290 - y1_output_loss: 0.5740 - y2_output_loss: 1.8866 - y1_output_root_mean_squared_error: 0.7589 - y2_output_root_mean_squared_error: 1.3613 - val_loss: 5.8416 - val_y1_output_loss: 1.1309 - val_y2_output_loss: 4.8802 - val_y1_output_root_mean_squared_error: 1.0713 - val_y2_output_root_mean_squared_error: 2.1666
# Epoch 110/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.1446 - y1_output_loss: 0.5490 - y2_output_loss: 1.6022 - y1_output_root_mean_squared_error: 0.7431 - y2_output_root_mean_squared_error: 1.2619 - val_loss: 4.2952 - val_y1_output_loss: 0.6574 - val_y2_output_loss: 3.5093 - val_y1_output_root_mean_squared_error: 0.8174 - val_y2_output_root_mean_squared_error: 1.9045
# Epoch 111/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.6507 - y1_output_loss: 0.6695 - y2_output_loss: 1.9760 - y1_output_root_mean_squared_error: 0.8213 - y2_output_root_mean_squared_error: 1.4058 - val_loss: 4.5534 - val_y1_output_loss: 0.8631 - val_y2_output_loss: 3.8587 - val_y1_output_root_mean_squared_error: 0.9426 - val_y2_output_root_mean_squared_error: 1.9144
# Epoch 112/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.2808 - y1_output_loss: 1.0679 - y2_output_loss: 3.2098 - y1_output_root_mean_squared_error: 1.0359 - y2_output_root_mean_squared_error: 1.7910 - val_loss: 5.3335 - val_y1_output_loss: 0.7218 - val_y2_output_loss: 4.8495 - val_y1_output_root_mean_squared_error: 0.8553 - val_y2_output_root_mean_squared_error: 2.1452
# Epoch 113/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.6408 - y1_output_loss: 0.6384 - y2_output_loss: 1.9896 - y1_output_root_mean_squared_error: 0.8011 - y2_output_root_mean_squared_error: 1.4139 - val_loss: 4.5375 - val_y1_output_loss: 1.1269 - val_y2_output_loss: 3.2927 - val_y1_output_root_mean_squared_error: 1.0653 - val_y2_output_root_mean_squared_error: 1.8446
# Epoch 114/500
# 614/614 [==============================] - 0s 133us/sample - loss: 1.9570 - y1_output_loss: 0.5219 - y2_output_loss: 1.4411 - y1_output_root_mean_squared_error: 0.7217 - y2_output_root_mean_squared_error: 1.1984 - val_loss: 4.0075 - val_y1_output_loss: 0.6842 - val_y2_output_loss: 3.4988 - val_y1_output_root_mean_squared_error: 0.8376 - val_y2_output_root_mean_squared_error: 1.8182
# Epoch 115/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.2216 - y1_output_loss: 0.6032 - y2_output_loss: 1.6507 - y1_output_root_mean_squared_error: 0.7630 - y2_output_root_mean_squared_error: 1.2804 - val_loss: 13.3910 - val_y1_output_loss: 4.8465 - val_y2_output_loss: 8.6941 - val_y1_output_root_mean_squared_error: 2.2255 - val_y2_output_root_mean_squared_error: 2.9048
# Epoch 116/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.0440 - y1_output_loss: 0.8376 - y2_output_loss: 2.3384 - y1_output_root_mean_squared_error: 0.8829 - y2_output_root_mean_squared_error: 1.5048 - val_loss: 20.3765 - val_y1_output_loss: 7.3861 - val_y2_output_loss: 12.6686 - val_y1_output_root_mean_squared_error: 2.7185 - val_y2_output_root_mean_squared_error: 3.6036
# Epoch 117/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.2708 - y1_output_loss: 0.7827 - y2_output_loss: 2.4873 - y1_output_root_mean_squared_error: 0.8889 - y2_output_root_mean_squared_error: 1.5750 - val_loss: 3.5846 - val_y1_output_loss: 0.7557 - val_y2_output_loss: 2.9673 - val_y1_output_root_mean_squared_error: 0.8762 - val_y2_output_root_mean_squared_error: 1.6784
# Epoch 118/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.3279 - y1_output_loss: 0.5403 - y2_output_loss: 1.7689 - y1_output_root_mean_squared_error: 0.7371 - y2_output_root_mean_squared_error: 1.3359 - val_loss: 2.6425 - val_y1_output_loss: 0.5578 - val_y2_output_loss: 2.1481 - val_y1_output_root_mean_squared_error: 0.7546 - val_y2_output_root_mean_squared_error: 1.4398
# Epoch 119/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.3558 - y1_output_loss: 0.5888 - y2_output_loss: 1.8202 - y1_output_root_mean_squared_error: 0.7654 - y2_output_root_mean_squared_error: 1.3304 - val_loss: 34.3939 - val_y1_output_loss: 8.8465 - val_y2_output_loss: 24.8690 - val_y1_output_root_mean_squared_error: 2.9802 - val_y2_output_root_mean_squared_error: 5.0510
# Epoch 120/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.6970 - y1_output_loss: 1.5865 - y2_output_loss: 4.0741 - y1_output_root_mean_squared_error: 1.2647 - y2_output_root_mean_squared_error: 2.0243 - val_loss: 4.3547 - val_y1_output_loss: 1.2998 - val_y2_output_loss: 3.2262 - val_y1_output_root_mean_squared_error: 1.1532 - val_y2_output_root_mean_squared_error: 1.7392
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4268 - y1_output_loss: 0.1207 - y2_output_loss: 0.3107 - y1_output_root_mean_squared_error: 0.3451 - y2_output_root_mean_squared_error: 0.5547 - val_loss: 2.0197 - val_y1_output_loss: 0.4497 - val_y2_output_loss: 1.5580 - val_y1_output_root_mean_squared_error: 0.6814 - val_y2_output_root_mean_squared_error: 1.2471
# Epoch 462/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.5976 - y1_output_loss: 0.1707 - y2_output_loss: 0.4240 - y1_output_root_mean_squared_error: 0.4141 - y2_output_root_mean_squared_error: 0.6528 - val_loss: 1.0985 - val_y1_output_loss: 0.2520 - val_y2_output_loss: 0.8184 - val_y1_output_root_mean_squared_error: 0.5108 - val_y2_output_root_mean_squared_error: 0.9152
# Epoch 463/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.5234 - y1_output_loss: 0.1568 - y2_output_loss: 0.3691 - y1_output_root_mean_squared_error: 0.3939 - y2_output_root_mean_squared_error: 0.6068 - val_loss: 1.4691 - val_y1_output_loss: 0.2887 - val_y2_output_loss: 1.1342 - val_y1_output_root_mean_squared_error: 0.5439 - val_y2_output_root_mean_squared_error: 1.0832
# Epoch 464/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3956 - y1_output_loss: 0.1167 - y2_output_loss: 0.2791 - y1_output_root_mean_squared_error: 0.3416 - y2_output_root_mean_squared_error: 0.5281 - val_loss: 1.4157 - val_y1_output_loss: 0.2394 - val_y2_output_loss: 1.1294 - val_y1_output_root_mean_squared_error: 0.4970 - val_y2_output_root_mean_squared_error: 1.0811
# Epoch 465/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.6624 - y1_output_loss: 0.1663 - y2_output_loss: 0.5085 - y1_output_root_mean_squared_error: 0.3966 - y2_output_root_mean_squared_error: 0.7107 - val_loss: 2.8815 - val_y1_output_loss: 0.5569 - val_y2_output_loss: 2.2412 - val_y1_output_root_mean_squared_error: 0.7538 - val_y2_output_root_mean_squared_error: 1.5209
# Epoch 466/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.5675 - y1_output_loss: 0.1571 - y2_output_loss: 0.4212 - y1_output_root_mean_squared_error: 0.3914 - y2_output_root_mean_squared_error: 0.6436 - val_loss: 2.2913 - val_y1_output_loss: 0.4422 - val_y2_output_loss: 1.7848 - val_y1_output_root_mean_squared_error: 0.6695 - val_y2_output_root_mean_squared_error: 1.3576
# Epoch 467/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4393 - y1_output_loss: 0.1262 - y2_output_loss: 0.3141 - y1_output_root_mean_squared_error: 0.3530 - y2_output_root_mean_squared_error: 0.5610 - val_loss: 1.1783 - val_y1_output_loss: 0.2857 - val_y2_output_loss: 0.8576 - val_y1_output_root_mean_squared_error: 0.5389 - val_y2_output_root_mean_squared_error: 0.9423
# Epoch 468/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3758 - y1_output_loss: 0.1118 - y2_output_loss: 0.2635 - y1_output_root_mean_squared_error: 0.3348 - y2_output_root_mean_squared_error: 0.5135 - val_loss: 1.9585 - val_y1_output_loss: 0.3506 - val_y2_output_loss: 1.5698 - val_y1_output_root_mean_squared_error: 0.5941 - val_y2_output_root_mean_squared_error: 1.2671
# Epoch 469/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4432 - y1_output_loss: 0.1208 - y2_output_loss: 0.3346 - y1_output_root_mean_squared_error: 0.3483 - y2_output_root_mean_squared_error: 0.5674 - val_loss: 2.8916 - val_y1_output_loss: 0.3716 - val_y2_output_loss: 2.4368 - val_y1_output_root_mean_squared_error: 0.6134 - val_y2_output_root_mean_squared_error: 1.5860
# Epoch 470/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.8510 - y1_output_loss: 0.2639 - y2_output_loss: 0.5810 - y1_output_root_mean_squared_error: 0.5157 - y2_output_root_mean_squared_error: 0.7649 - val_loss: 1.2271 - val_y1_output_loss: 0.2399 - val_y2_output_loss: 0.9485 - val_y1_output_root_mean_squared_error: 0.4983 - val_y2_output_root_mean_squared_error: 0.9893
# Epoch 471/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.5109 - y1_output_loss: 0.1283 - y2_output_loss: 0.3893 - y1_output_root_mean_squared_error: 0.3587 - y2_output_root_mean_squared_error: 0.6182 - val_loss: 2.4897 - val_y1_output_loss: 0.3859 - val_y2_output_loss: 2.1273 - val_y1_output_root_mean_squared_error: 0.6300 - val_y2_output_root_mean_squared_error: 1.4466
# Epoch 472/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4735 - y1_output_loss: 0.1357 - y2_output_loss: 0.3418 - y1_output_root_mean_squared_error: 0.3683 - y2_output_root_mean_squared_error: 0.5812 - val_loss: 1.6031 - val_y1_output_loss: 0.3415 - val_y2_output_loss: 1.2565 - val_y1_output_root_mean_squared_error: 0.5944 - val_y2_output_root_mean_squared_error: 1.1179
# Epoch 473/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4314 - y1_output_loss: 0.1192 - y2_output_loss: 0.3113 - y1_output_root_mean_squared_error: 0.3463 - y2_output_root_mean_squared_error: 0.5581 - val_loss: 1.5436 - val_y1_output_loss: 0.2511 - val_y2_output_loss: 1.2395 - val_y1_output_root_mean_squared_error: 0.5077 - val_y2_output_root_mean_squared_error: 1.1339
# Epoch 474/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.5528 - y1_output_loss: 0.1482 - y2_output_loss: 0.4116 - y1_output_root_mean_squared_error: 0.3852 - y2_output_root_mean_squared_error: 0.6360 - val_loss: 2.6349 - val_y1_output_loss: 0.2516 - val_y2_output_loss: 2.3365 - val_y1_output_root_mean_squared_error: 0.5062 - val_y2_output_root_mean_squared_error: 1.5423
# Epoch 475/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4873 - y1_output_loss: 0.1347 - y2_output_loss: 0.3497 - y1_output_root_mean_squared_error: 0.3684 - y2_output_root_mean_squared_error: 0.5929 - val_loss: 1.3027 - val_y1_output_loss: 0.3076 - val_y2_output_loss: 0.9527 - val_y1_output_root_mean_squared_error: 0.5622 - val_y2_output_root_mean_squared_error: 0.9933
# Epoch 476/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3432 - y1_output_loss: 0.1124 - y2_output_loss: 0.2296 - y1_output_root_mean_squared_error: 0.3359 - y2_output_root_mean_squared_error: 0.4800 - val_loss: 1.2074 - val_y1_output_loss: 0.2709 - val_y2_output_loss: 0.9221 - val_y1_output_root_mean_squared_error: 0.5302 - val_y2_output_root_mean_squared_error: 0.9625
# Epoch 477/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.5497 - y1_output_loss: 0.1400 - y2_output_loss: 0.4091 - y1_output_root_mean_squared_error: 0.3754 - y2_output_root_mean_squared_error: 0.6394 - val_loss: 1.3950 - val_y1_output_loss: 0.2385 - val_y2_output_loss: 1.1392 - val_y1_output_root_mean_squared_error: 0.4963 - val_y2_output_root_mean_squared_error: 1.0718
# Epoch 478/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.5255 - y1_output_loss: 0.1333 - y2_output_loss: 0.3909 - y1_output_root_mean_squared_error: 0.3648 - y2_output_root_mean_squared_error: 0.6264 - val_loss: 1.7277 - val_y1_output_loss: 0.2702 - val_y2_output_loss: 1.4598 - val_y1_output_root_mean_squared_error: 0.5291 - val_y2_output_root_mean_squared_error: 1.2032
# Epoch 479/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4808 - y1_output_loss: 0.1336 - y2_output_loss: 0.3437 - y1_output_root_mean_squared_error: 0.3665 - y2_output_root_mean_squared_error: 0.5887 - val_loss: 1.1625 - val_y1_output_loss: 0.2660 - val_y2_output_loss: 0.8853 - val_y1_output_root_mean_squared_error: 0.5250 - val_y2_output_root_mean_squared_error: 0.9417
# Epoch 480/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4209 - y1_output_loss: 0.1294 - y2_output_loss: 0.2961 - y1_output_root_mean_squared_error: 0.3557 - y2_output_root_mean_squared_error: 0.5426 - val_loss: 1.7387 - val_y1_output_loss: 0.3073 - val_y2_output_loss: 1.4288 - val_y1_output_root_mean_squared_error: 0.5643 - val_y2_output_root_mean_squared_error: 1.1918
# Epoch 481/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4076 - y1_output_loss: 0.1173 - y2_output_loss: 0.2871 - y1_output_root_mean_squared_error: 0.3437 - y2_output_root_mean_squared_error: 0.5380 - val_loss: 1.0189 - val_y1_output_loss: 0.2318 - val_y2_output_loss: 0.7616 - val_y1_output_root_mean_squared_error: 0.4886 - val_y2_output_root_mean_squared_error: 0.8833
# Epoch 482/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4793 - y1_output_loss: 0.1409 - y2_output_loss: 0.3361 - y1_output_root_mean_squared_error: 0.3771 - y2_output_root_mean_squared_error: 0.5806 - val_loss: 1.2613 - val_y1_output_loss: 0.2573 - val_y2_output_loss: 0.9659 - val_y1_output_root_mean_squared_error: 0.5150 - val_y2_output_root_mean_squared_error: 0.9980
# Epoch 483/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4332 - y1_output_loss: 0.1369 - y2_output_loss: 0.2962 - y1_output_root_mean_squared_error: 0.3682 - y2_output_root_mean_squared_error: 0.5455 - val_loss: 1.5917 - val_y1_output_loss: 0.3409 - val_y2_output_loss: 1.2050 - val_y1_output_root_mean_squared_error: 0.5854 - val_y2_output_root_mean_squared_error: 1.1176
# Epoch 484/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4185 - y1_output_loss: 0.1328 - y2_output_loss: 0.2836 - y1_output_root_mean_squared_error: 0.3636 - y2_output_root_mean_squared_error: 0.5351 - val_loss: 1.1769 - val_y1_output_loss: 0.2823 - val_y2_output_loss: 0.8623 - val_y1_output_root_mean_squared_error: 0.5373 - val_y2_output_root_mean_squared_error: 0.9424
# Epoch 485/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.7261 - y1_output_loss: 0.1922 - y2_output_loss: 0.5274 - y1_output_root_mean_squared_error: 0.4403 - y2_output_root_mean_squared_error: 0.7296 - val_loss: 1.1166 - val_y1_output_loss: 0.2541 - val_y2_output_loss: 0.8390 - val_y1_output_root_mean_squared_error: 0.5133 - val_y2_output_root_mean_squared_error: 0.9236
# Epoch 486/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3911 - y1_output_loss: 0.1057 - y2_output_loss: 0.2843 - y1_output_root_mean_squared_error: 0.3258 - y2_output_root_mean_squared_error: 0.5338 - val_loss: 1.1051 - val_y1_output_loss: 0.2560 - val_y2_output_loss: 0.8348 - val_y1_output_root_mean_squared_error: 0.5122 - val_y2_output_root_mean_squared_error: 0.9180
# Epoch 487/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3777 - y1_output_loss: 0.1158 - y2_output_loss: 0.2734 - y1_output_root_mean_squared_error: 0.3347 - y2_output_root_mean_squared_error: 0.5155 - val_loss: 1.4485 - val_y1_output_loss: 0.2954 - val_y2_output_loss: 1.1068 - val_y1_output_root_mean_squared_error: 0.5504 - val_y2_output_root_mean_squared_error: 1.0703
# Epoch 488/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4211 - y1_output_loss: 0.1366 - y2_output_loss: 0.2902 - y1_output_root_mean_squared_error: 0.3665 - y2_output_root_mean_squared_error: 0.5355 - val_loss: 1.5388 - val_y1_output_loss: 0.2297 - val_y2_output_loss: 1.3218 - val_y1_output_root_mean_squared_error: 0.4871 - val_y2_output_root_mean_squared_error: 1.1408
# Epoch 489/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.5297 - y1_output_loss: 0.1416 - y2_output_loss: 0.3889 - y1_output_root_mean_squared_error: 0.3761 - y2_output_root_mean_squared_error: 0.6231 - val_loss: 2.1744 - val_y1_output_loss: 0.3395 - val_y2_output_loss: 1.7846 - val_y1_output_root_mean_squared_error: 0.5864 - val_y2_output_root_mean_squared_error: 1.3530
# Epoch 490/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4689 - y1_output_loss: 0.1268 - y2_output_loss: 0.3381 - y1_output_root_mean_squared_error: 0.3574 - y2_output_root_mean_squared_error: 0.5841 - val_loss: 1.1610 - val_y1_output_loss: 0.2526 - val_y2_output_loss: 0.8856 - val_y1_output_root_mean_squared_error: 0.5116 - val_y2_output_root_mean_squared_error: 0.9483
# Epoch 491/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4327 - y1_output_loss: 0.1118 - y2_output_loss: 0.3174 - y1_output_root_mean_squared_error: 0.3355 - y2_output_root_mean_squared_error: 0.5659 - val_loss: 1.0328 - val_y1_output_loss: 0.2441 - val_y2_output_loss: 0.7622 - val_y1_output_root_mean_squared_error: 0.5000 - val_y2_output_root_mean_squared_error: 0.8848
# Epoch 492/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.5238 - y1_output_loss: 0.1364 - y2_output_loss: 0.3864 - y1_output_root_mean_squared_error: 0.3692 - y2_output_root_mean_squared_error: 0.6225 - val_loss: 1.1701 - val_y1_output_loss: 0.2891 - val_y2_output_loss: 0.8579 - val_y1_output_root_mean_squared_error: 0.5429 - val_y2_output_root_mean_squared_error: 0.9356
# Epoch 493/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4358 - y1_output_loss: 0.1179 - y2_output_loss: 0.3166 - y1_output_root_mean_squared_error: 0.3438 - y2_output_root_mean_squared_error: 0.5636 - val_loss: 1.5234 - val_y1_output_loss: 0.3400 - val_y2_output_loss: 1.1355 - val_y1_output_root_mean_squared_error: 0.5892 - val_y2_output_root_mean_squared_error: 1.0845
# Epoch 494/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4004 - y1_output_loss: 0.1150 - y2_output_loss: 0.2822 - y1_output_root_mean_squared_error: 0.3404 - y2_output_root_mean_squared_error: 0.5334 - val_loss: 1.1484 - val_y1_output_loss: 0.2427 - val_y2_output_loss: 0.8718 - val_y1_output_root_mean_squared_error: 0.4988 - val_y2_output_root_mean_squared_error: 0.9485
# Epoch 495/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4033 - y1_output_loss: 0.1325 - y2_output_loss: 0.2709 - y1_output_root_mean_squared_error: 0.3630 - y2_output_root_mean_squared_error: 0.5211 - val_loss: 1.3228 - val_y1_output_loss: 0.3947 - val_y2_output_loss: 0.9107 - val_y1_output_root_mean_squared_error: 0.6397 - val_y2_output_root_mean_squared_error: 0.9558
# Epoch 496/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4603 - y1_output_loss: 0.1239 - y2_output_loss: 0.3361 - y1_output_root_mean_squared_error: 0.3521 - y2_output_root_mean_squared_error: 0.5800 - val_loss: 1.1951 - val_y1_output_loss: 0.2336 - val_y2_output_loss: 0.9275 - val_y1_output_root_mean_squared_error: 0.4906 - val_y2_output_root_mean_squared_error: 0.9770
# Epoch 497/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3920 - y1_output_loss: 0.1138 - y2_output_loss: 0.2749 - y1_output_root_mean_squared_error: 0.3385 - y2_output_root_mean_squared_error: 0.5267 - val_loss: 1.1190 - val_y1_output_loss: 0.2957 - val_y2_output_loss: 0.8038 - val_y1_output_root_mean_squared_error: 0.5513 - val_y2_output_root_mean_squared_error: 0.9028
# Epoch 498/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4243 - y1_output_loss: 0.1277 - y2_output_loss: 0.2936 - y1_output_root_mean_squared_error: 0.3578 - y2_output_root_mean_squared_error: 0.5443 - val_loss: 1.2346 - val_y1_output_loss: 0.2951 - val_y2_output_loss: 0.9270 - val_y1_output_root_mean_squared_error: 0.5456 - val_y2_output_root_mean_squared_error: 0.9680
# Epoch 499/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3358 - y1_output_loss: 0.1025 - y2_output_loss: 0.2378 - y1_output_root_mean_squared_error: 0.3171 - y2_output_root_mean_squared_error: 0.4851 - val_loss: 1.6740 - val_y1_output_loss: 0.3103 - val_y2_output_loss: 1.3455 - val_y1_output_root_mean_squared_error: 0.5675 - val_y2_output_root_mean_squared_error: 1.1627
# Epoch 500/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3884 - y1_output_loss: 0.1071 - y2_output_loss: 0.2797 - y1_output_root_mean_squared_error: 0.3277 - y2_output_root_mean_squared_error: 0.5301 - val_loss: 1.1260 - val_y1_output_loss: 0.2320 - val_y2_output_loss: 0.8541 - val_y1_output_root_mean_squared_error: 0.4902 - val_y2_output_root_mean_squared_error: 0.9411

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 39us/sample - loss: 1.1260 - y1_output_loss: 0.2358 - y2_output_loss: 0.8768 - y1_output_root_mean_squared_error: 0.4902 - y2_output_root_mean_squared_error: 0.9411
# Loss = 1.1260248306509737, Y1_loss = 0.23583558201789856, Y1_mse = 0.490176260471344, Y2_loss = 0.8768495321273804, Y2_mse = 0.9411440491676331

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
